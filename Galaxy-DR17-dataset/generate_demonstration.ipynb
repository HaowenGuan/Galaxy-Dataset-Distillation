# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
n = 200 - 10000

data = []
for i in range(10000):
    x = np.array(range(500))
    y = np.random.normal(size=500)
    data.append(np.corrcoef(x, y)[0, 1])
print(np.std(data))
print(np.sqrt(1/498))
_ = plt.hist(data, bins=50)
# Out:
# 0.044503759700678575
# 0.04481107149482208

# %%
pd_data = pd.read_csv('wandb_export_2023-02-20T21_34_25.654-05_00.csv', delimiter=',')

# %%
print(pd_data.keys())
# Out:
# Index(['Step', 'desert-butterfly-258 - Next_Epoch_Test_Loss',
#        'desert-butterfly-258 - Next_Epoch_Test_Loss__MIN',
#        'desert-butterfly-258 - Next_Epoch_Test_Loss__MAX'],
#       dtype='object')

# %%
plt.plot(pd_data['Step'], pd_data['desert-butterfly-258 - Next_Epoch_Test_Loss'])
x = pd_data['Step']
y = pd_data['desert-butterfly-258 - Next_Epoch_Test_Loss']

# %%
cc = []
for i in range(200, len(pd_data['Step'])):
    cc.append(np.corrcoef(x[:i], y[:i])[0, 1])
plt.plot(cc)

# %%
cc = []
for i in range(200, len(pd_data['Step']) - 200):
    cc.append(np.mean(y[i - 200:i]) / np.mean(y[i:i + 200]))
plt.plot(cc)

# %%
ov = pd.read_csv("overfitting.csv")
print(ov.keys())
x = ov['Step']
y = ov['new stage distill 5ipc - Next_Epoch_Test_Loss']
plt.plot(x[:-2], y[:-2])
# Out:
# Index(['Step', 'new stage distill 5ipc - Next_Epoch_Test_Loss',
#        'new stage distill 5ipc - Next_Epoch_Test_Loss__MIN',
#        'new stage distill 5ipc - Next_Epoch_Test_Loss__MAX'],
#       dtype='object')

# %%
cc = []
for i in range(200, len(ov['Step'])):
    cc.append(np.corrcoef(x[:i], y[:i])[0, 1])
plt.plot(cc)
